# %% [markdown]
# <a href="https://colab.research.google.com/github/deshm084/Distributed-ML-Pipeline-with-Ray-Tune-MLflow/blob/main/Distributed_ML_Pipeline_with_Ray_Tune_MLflow.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install ray[tune] mlflow
# Out:
# Requirement already satisfied: mlflow in /usr/local/lib/python3.12/dist-packages (3.8.1)
# Requirement already satisfied: ray[tune] in /usr/local/lib/python3.12/dist-packages (2.53.0)
# Requirement already satisfied: click>=7.0 in /usr/local/lib/python3.12/dist-packages (from ray[tune]) (8.3.1)
# Requirement already satisfied: filelock in /usr/local/lib/python3.12/dist-packages (from ray[tune]) (3.20.0)
# Requirement already satisfied: jsonschema in /usr/local/lib/python3.12/dist-packages (from ray[tune]) (4.25.1)
# Requirement already satisfied: msgpack<2.0.0,>=1.0.0 in /usr/local/lib/python3.12/dist-packages (from ray[tune]) (1.1.2)
# Requirement already satisfied: packaging>=24.2 in /usr/local/lib/python3.12/dist-packages (from ray[tune]) (25.0)
# Requirement already satisfied: protobuf>=3.20.3 in /usr/local/lib/python3.12/dist-packages (from ray[tune]) (5.29.5)
# Requirement already satisfied: pyyaml in /usr/local/lib/python3.12/dist-packages (from ray[tune]) (6.0.3)
# Requirement already satisfied: requests in /usr/local/lib/python3.12/dist-packages (from ray[tune]) (2.32.4)
# Requirement already satisfied: pandas in /usr/local/lib/python3.12/dist-packages (from ray[tune]) (2.2.2)
# Requirement already satisfied: pydantic!=2.0.*,!=2.1.*,!=2.10.*,!=2.11.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,!=2.8.*,!=2.9.*,<3 in /usr/local/lib/python3.12/dist-packages (from ray[tune]) (2.12.3)
# Requirement already satisfied: tensorboardX>=1.9 in /usr/local/lib/python3.12/dist-packages (from ray[tune]) (2.6.4)
# Requirement already satisfied: pyarrow>=9.0.0 in /usr/local/lib/python3.12/dist-packages (from ray[tune]) (18.1.0)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.12/dist-packages (from ray[tune]) (2025.3.0)
# Requirement already satisfied: mlflow-skinny==3.8.1 in /usr/local/lib/python3.12/dist-packages (from mlflow) (3.8.1)
# Requirement already satisfied: mlflow-tracing==3.8.1 in /usr/local/lib/python3.12/dist-packages (from mlflow) (3.8.1)
# Requirement already satisfied: Flask-CORS<7 in /usr/local/lib/python3.12/dist-packages (from mlflow) (6.0.2)
# Requirement already satisfied: Flask<4 in /usr/local/lib/python3.12/dist-packages (from mlflow) (3.1.2)
# Requirement already satisfied: alembic!=1.10.0,<2 in /usr/local/lib/python3.12/dist-packages (from mlflow) (1.17.2)
# Requirement already satisfied: cryptography<47,>=43.0.0 in /usr/local/lib/python3.12/dist-packages (from mlflow) (43.0.3)
# Requirement already satisfied: docker<8,>=4.0.0 in /usr/local/lib/python3.12/dist-packages (from mlflow) (7.1.0)
# Requirement already satisfied: graphene<4 in /usr/local/lib/python3.12/dist-packages (from mlflow) (3.4.3)
# Requirement already satisfied: gunicorn<24 in /usr/local/lib/python3.12/dist-packages (from mlflow) (23.0.0)
# Requirement already satisfied: huey<3,>=2.5.0 in /usr/local/lib/python3.12/dist-packages (from mlflow) (2.6.0)
# Requirement already satisfied: matplotlib<4 in /usr/local/lib/python3.12/dist-packages (from mlflow) (3.10.0)
# Requirement already satisfied: numpy<3 in /usr/local/lib/python3.12/dist-packages (from mlflow) (2.0.2)
# Requirement already satisfied: scikit-learn<2 in /usr/local/lib/python3.12/dist-packages (from mlflow) (1.6.1)
# Requirement already satisfied: scipy<2 in /usr/local/lib/python3.12/dist-packages (from mlflow) (1.16.3)
# Requirement already satisfied: sqlalchemy<3,>=1.4.0 in /usr/local/lib/python3.12/dist-packages (from mlflow) (2.0.45)
# Requirement already satisfied: cachetools<7,>=5.0.0 in /usr/local/lib/python3.12/dist-packages (from mlflow-skinny==3.8.1->mlflow) (6.2.4)
# Requirement already satisfied: cloudpickle<4 in /usr/local/lib/python3.12/dist-packages (from mlflow-skinny==3.8.1->mlflow) (3.1.2)
# Requirement already satisfied: databricks-sdk<1,>=0.20.0 in /usr/local/lib/python3.12/dist-packages (from mlflow-skinny==3.8.1->mlflow) (0.77.0)
# Requirement already satisfied: fastapi<1 in /usr/local/lib/python3.12/dist-packages (from mlflow-skinny==3.8.1->mlflow) (0.123.10)
# Requirement already satisfied: gitpython<4,>=3.1.9 in /usr/local/lib/python3.12/dist-packages (from mlflow-skinny==3.8.1->mlflow) (3.1.45)
# Requirement already satisfied: importlib_metadata!=4.7.0,<9,>=3.7.0 in /usr/local/lib/python3.12/dist-packages (from mlflow-skinny==3.8.1->mlflow) (8.7.0)
# Requirement already satisfied: opentelemetry-api<3,>=1.9.0 in /usr/local/lib/python3.12/dist-packages (from mlflow-skinny==3.8.1->mlflow) (1.37.0)
# Requirement already satisfied: opentelemetry-proto<3,>=1.9.0 in /usr/local/lib/python3.12/dist-packages (from mlflow-skinny==3.8.1->mlflow) (1.37.0)
# Requirement already satisfied: opentelemetry-sdk<3,>=1.9.0 in /usr/local/lib/python3.12/dist-packages (from mlflow-skinny==3.8.1->mlflow) (1.37.0)
# Requirement already satisfied: python-dotenv<2,>=0.19.0 in /usr/local/lib/python3.12/dist-packages (from mlflow-skinny==3.8.1->mlflow) (1.2.1)
# Requirement already satisfied: sqlparse<1,>=0.4.0 in /usr/local/lib/python3.12/dist-packages (from mlflow-skinny==3.8.1->mlflow) (0.5.4)
# Requirement already satisfied: typing-extensions<5,>=4.0.0 in /usr/local/lib/python3.12/dist-packages (from mlflow-skinny==3.8.1->mlflow) (4.15.0)
# Requirement already satisfied: uvicorn<1 in /usr/local/lib/python3.12/dist-packages (from mlflow-skinny==3.8.1->mlflow) (0.38.0)
# Requirement already satisfied: Mako in /usr/local/lib/python3.12/dist-packages (from alembic!=1.10.0,<2->mlflow) (1.3.10)
# Requirement already satisfied: cffi>=1.12 in /usr/local/lib/python3.12/dist-packages (from cryptography<47,>=43.0.0->mlflow) (2.0.0)
# Requirement already satisfied: urllib3>=1.26.0 in /usr/local/lib/python3.12/dist-packages (from docker<8,>=4.0.0->mlflow) (2.5.0)
# Requirement already satisfied: blinker>=1.9.0 in /usr/local/lib/python3.12/dist-packages (from Flask<4->mlflow) (1.9.0)
# Requirement already satisfied: itsdangerous>=2.2.0 in /usr/local/lib/python3.12/dist-packages (from Flask<4->mlflow) (2.2.0)
# Requirement already satisfied: jinja2>=3.1.2 in /usr/local/lib/python3.12/dist-packages (from Flask<4->mlflow) (3.1.6)
# Requirement already satisfied: markupsafe>=2.1.1 in /usr/local/lib/python3.12/dist-packages (from Flask<4->mlflow) (3.0.3)
# Requirement already satisfied: werkzeug>=3.1.0 in /usr/local/lib/python3.12/dist-packages (from Flask<4->mlflow) (3.1.4)
# Requirement already satisfied: graphql-core<3.3,>=3.1 in /usr/local/lib/python3.12/dist-packages (from graphene<4->mlflow) (3.2.7)
# Requirement already satisfied: graphql-relay<3.3,>=3.1 in /usr/local/lib/python3.12/dist-packages (from graphene<4->mlflow) (3.2.0)
# Requirement already satisfied: python-dateutil<3,>=2.7.0 in /usr/local/lib/python3.12/dist-packages (from graphene<4->mlflow) (2.9.0.post0)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib<4->mlflow) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.12/dist-packages (from matplotlib<4->mlflow) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.12/dist-packages (from matplotlib<4->mlflow) (4.61.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib<4->mlflow) (1.4.9)
# Requirement already satisfied: pillow>=8 in /usr/local/lib/python3.12/dist-packages (from matplotlib<4->mlflow) (11.3.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib<4->mlflow) (3.2.5)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.12/dist-packages (from pandas->ray[tune]) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.12/dist-packages (from pandas->ray[tune]) (2025.3)
# Requirement already satisfied: annotated-types>=0.6.0 in /usr/local/lib/python3.12/dist-packages (from pydantic!=2.0.*,!=2.1.*,!=2.10.*,!=2.11.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,!=2.8.*,!=2.9.*,<3->ray[tune]) (0.7.0)
# Requirement already satisfied: pydantic-core==2.41.4 in /usr/local/lib/python3.12/dist-packages (from pydantic!=2.0.*,!=2.1.*,!=2.10.*,!=2.11.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,!=2.8.*,!=2.9.*,<3->ray[tune]) (2.41.4)
# Requirement already satisfied: typing-inspection>=0.4.2 in /usr/local/lib/python3.12/dist-packages (from pydantic!=2.0.*,!=2.1.*,!=2.10.*,!=2.11.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,!=2.8.*,!=2.9.*,<3->ray[tune]) (0.4.2)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests->ray[tune]) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.12/dist-packages (from requests->ray[tune]) (3.11)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.12/dist-packages (from requests->ray[tune]) (2025.11.12)
# Requirement already satisfied: joblib>=1.2.0 in /usr/local/lib/python3.12/dist-packages (from scikit-learn<2->mlflow) (1.5.3)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /usr/local/lib/python3.12/dist-packages (from scikit-learn<2->mlflow) (3.6.0)
# Requirement already satisfied: greenlet>=1 in /usr/local/lib/python3.12/dist-packages (from sqlalchemy<3,>=1.4.0->mlflow) (3.3.0)
# Requirement already satisfied: attrs>=22.2.0 in /usr/local/lib/python3.12/dist-packages (from jsonschema->ray[tune]) (25.4.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in /usr/local/lib/python3.12/dist-packages (from jsonschema->ray[tune]) (2025.9.1)
# Requirement already satisfied: referencing>=0.28.4 in /usr/local/lib/python3.12/dist-packages (from jsonschema->ray[tune]) (0.37.0)
# Requirement already satisfied: rpds-py>=0.7.1 in /usr/local/lib/python3.12/dist-packages (from jsonschema->ray[tune]) (0.30.0)
# Requirement already satisfied: pycparser in /usr/local/lib/python3.12/dist-packages (from cffi>=1.12->cryptography<47,>=43.0.0->mlflow) (2.23)
# Requirement already satisfied: google-auth~=2.0 in /usr/local/lib/python3.12/dist-packages (from databricks-sdk<1,>=0.20.0->mlflow-skinny==3.8.1->mlflow) (2.43.0)
# Requirement already satisfied: starlette<0.51.0,>=0.40.0 in /usr/local/lib/python3.12/dist-packages (from fastapi<1->mlflow-skinny==3.8.1->mlflow) (0.50.0)
# Requirement already satisfied: annotated-doc>=0.0.2 in /usr/local/lib/python3.12/dist-packages (from fastapi<1->mlflow-skinny==3.8.1->mlflow) (0.0.4)
# Requirement already satisfied: gitdb<5,>=4.0.1 in /usr/local/lib/python3.12/dist-packages (from gitpython<4,>=3.1.9->mlflow-skinny==3.8.1->mlflow) (4.0.12)
# Requirement already satisfied: zipp>=3.20 in /usr/local/lib/python3.12/dist-packages (from importlib_metadata!=4.7.0,<9,>=3.7.0->mlflow-skinny==3.8.1->mlflow) (3.23.0)
# Requirement already satisfied: opentelemetry-semantic-conventions==0.58b0 in /usr/local/lib/python3.12/dist-packages (from opentelemetry-sdk<3,>=1.9.0->mlflow-skinny==3.8.1->mlflow) (0.58b0)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.12/dist-packages (from python-dateutil<3,>=2.7.0->graphene<4->mlflow) (1.17.0)
# Requirement already satisfied: h11>=0.8 in /usr/local/lib/python3.12/dist-packages (from uvicorn<1->mlflow-skinny==3.8.1->mlflow) (0.16.0)
# Requirement already satisfied: smmap<6,>=3.0.1 in /usr/local/lib/python3.12/dist-packages (from gitdb<5,>=4.0.1->gitpython<4,>=3.1.9->mlflow-skinny==3.8.1->mlflow) (5.0.2)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /usr/local/lib/python3.12/dist-packages (from google-auth~=2.0->databricks-sdk<1,>=0.20.0->mlflow-skinny==3.8.1->mlflow) (0.4.2)
# Requirement already satisfied: rsa<5,>=3.1.4 in /usr/local/lib/python3.12/dist-packages (from google-auth~=2.0->databricks-sdk<1,>=0.20.0->mlflow-skinny==3.8.1->mlflow) (4.9.1)
# Requirement already satisfied: anyio<5,>=3.6.2 in /usr/local/lib/python3.12/dist-packages (from starlette<0.51.0,>=0.40.0->fastapi<1->mlflow-skinny==3.8.1->mlflow) (4.12.0)
# Requirement already satisfied: pyasn1<0.7.0,>=0.6.1 in /usr/local/lib/python3.12/dist-packages (from pyasn1-modules>=0.2.1->google-auth~=2.0->databricks-sdk<1,>=0.20.0->mlflow-skinny==3.8.1->mlflow) (0.6.1)

# %%
import os
import time
import mlflow
import mlflow.sklearn
from sklearn.datasets import load_diabetes
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestRegressor
from sklearn.metrics import mean_squared_error
from ray import tune
from ray.tune.search.optuna import OptunaSearch  # Smart search algorithm
import numpy as np # Import numpy for sqrt

# --- 1. The Training Function (The "Minion" Logic) ---
# This function runs on a separate process (Worker)
def train_model(config):
    # Ensure MLflow experiment is set for each worker process
    mlflow.set_experiment("Diabetes_Distributed_tuning")

    # 1. Load Data (Each worker loads its own copy or reads from shared storage)
    data = load_diabetes()
    X_train, X_test, y_train, y_test = train_test_split(data.data, data.target, test_size=0.2)

    # 2. Build Model using hyperparams passed in 'config'
    model = RandomForestRegressor(
        n_estimators=config["n_estimators"],
        max_depth=config["max_depth"],
        min_samples_split=config["min_samples_split"]
    )

    # 3. Train
    model.fit(X_train, y_train)
    predictions = model.predict(X_test)
    # Fix: Calculate RMSE by taking the square root of MSE
    mse = mean_squared_error(y_test, predictions)
    rmse = np.sqrt(mse)

    # 4. Log to MLflow (The "Registry")
    # We create a new run for every trial
    with mlflow.start_run(nested=True):
        mlflow.log_params(config)
        mlflow.log_metric("rmse", rmse)
        # We tag this model so we can find it later
        mlflow.set_tag("mode", "distributed_trial")

    # 5. Report back to Ray (The "Boss")
    tune.report({"rmse": rmse})

# --- 2. The Orchestrator (The "Boss") ---
def run_distributed_pipeline():
    print("🚀 Initializing Ray Cluster...")
    # Define the search space (The Grid)
    search_space = {
        "n_estimators": tune.randint(50, 500),
        "max_depth": tune.randint(2, 20),
        "min_samples_split": tune.randint(2, 10)
    }

    # The mlflow.set_experiment call has been moved to train_model function
    # mlflow.set_experiment("Diabetes_Distributed_tuning")

    print("⚡ Starting Distributed Tuning (Running parallel trials)...")

    # This executes the training function in parallel across available cores
    analysis = tune.run(
        train_model,
        config=search_space,
        metric="rmse",
        mode="min",            # We want to minimize Error
        num_samples=10,        # Run 10 different experiments
        resources_per_trial={"cpu": 1}, # 1 CPU per worker
        verbose=1
    )

    print("\n✅ Tuning Complete.")
    best_trial = analysis.get_best_trial("rmse", "min", "last")
    print(f"🏆 Best Hyperparameters found: {best_trial.config}")
    print(f"📉 Lowest RMSE: {best_trial.last_result['rmse']:.4f}")

    return best_trial.config
# --- 3. Production Deployment Simulation (FIXED) ---
def register_and_serve(best_config):
    print("\n📦 Promoting Best Model to Production Registry...")

    # Retrain final model on all data
    data = load_diabetes()
    model = RandomForestRegressor(
        n_estimators=best_config["n_estimators"],
        max_depth=best_config["max_depth"],
        min_samples_split=best_config["min_samples_split"]
    )
    model.fit(data.data, data.target)

    # Log the final "Production" model
    # We capture the 'run' object to get the ID safely
    with mlflow.start_run(run_name="PRODUCTION_MODEL") as run:
        mlflow.log_params(best_config)
        mlflow.sklearn.log_model(model, "random_forest_model")

        # --- THE FIX ---
        # Instead of guessing the file path, we construct the official URI
        # Format: runs:/<run_id>/<artifact_path>
        run_id = run.info.run_id
        model_uri = f"runs:/{run_id}/random_forest_model"

        print(f"🔒 Model Versioned at: {model_uri}")

        # SIMULATE SERVING
        print("\n🤖 Mock Inference Server Online...")

        # This instructs MLflow to look up the run internally
        loaded_model = mlflow.sklearn.load_model(model_uri)

        sample_data = data.data[0:1]
        prediction = loaded_model.predict(sample_data)
        print(f"   Input: Patient Data [0.03, 0.05, ...]")
        print(f"   Prediction: Disease Progression = {prediction[0]:.2f}")

if __name__ == "__main__":
    # If best_config is already in memory from the previous cell, you can just run:
    # register_and_serve(best_config)

    # Otherwise, re-run the full pipeline:
    best_config = run_distributed_pipeline()
    register_and_serve(best_config)
# Out:
# 🚀 Initializing Ray Cluster...
# ⚡ Starting Distributed Tuning (Running parallel trials)...
# +--------------------------------------------------------------------+
# | Configuration for experiment     train_model_2026-01-11_21-47-02   |
# +--------------------------------------------------------------------+
# | Search algorithm                 BasicVariantGenerator             |
# | Scheduler                        FIFOScheduler                     |
# | Number of trials                 10                                |
# +--------------------------------------------------------------------+
#
# View detailed results here: /root/ray_results/train_model_2026-01-11_21-47-02
# To visualize your results with TensorBoard, run: `tensorboard --logdir /tmp/ray/session_2026-01-11_20-08-27_551419_858/artifacts/2026-01-11_21-47-02/train_model_2026-01-11_21-47-02/driver_artifacts`
#
# Trial status: 10 PENDING
# Current time: 2026-01-11 21:47:03. Total running time: 0s
# Logical resource usage: 0/2 CPUs, 0/0 GPUs
# +-----------------------------------------------------------------------------------------+
# | Trial name                status       n_estimators     max_depth     min_samples_split |
# +-----------------------------------------------------------------------------------------+
# | train_model_108ae_00000   PENDING               161            19                     8 |
# | train_model_108ae_00001   PENDING               139            19                     7 |
# | train_model_108ae_00002   PENDING               120             2                     9 |
# | train_model_108ae_00003   PENDING               438            18                     6 |
# | train_model_108ae_00004   PENDING               113            13                     8 |
# | train_model_108ae_00005   PENDING               159            11                     8 |
# | train_model_108ae_00006   PENDING               457            12                     4 |
# | train_model_108ae_00007   PENDING               389            13                     3 |
# | train_model_108ae_00008   PENDING               149             6                     6 |
# | train_model_108ae_00009   PENDING               155            16                     6 |
# +-----------------------------------------------------------------------------------------+
#
# Trial train_model_108ae_00000 started with configuration:
# +----------------------------------------------+
# | Trial train_model_108ae_00000 config         |
# +----------------------------------------------+
# | max_depth                                 19 |
# | min_samples_split                          8 |
# | n_estimators                             161 |
# +----------------------------------------------+
# (train_model pid=62148) 2026/01/11 21:47:30 INFO mlflow.store.db.utils: Creating initial MLflow database tables...
# (train_model pid=62148) 2026/01/11 21:47:30 INFO mlflow.store.db.utils: Updating database tables
# (train_model pid=62148) 2026/01/11 21:47:30 INFO alembic.runtime.migration: Context impl SQLiteImpl.
# (train_model pid=62148) 2026/01/11 21:47:30 INFO alembic.runtime.migration: Will assume non-transactional DDL.
# Trial train_model_108ae_00001 started with configuration:
# +----------------------------------------------+
# | Trial train_model_108ae_00001 config         |
# +----------------------------------------------+
# | max_depth                                 19 |
# | min_samples_split                          7 |
# | n_estimators                             139 |
# +----------------------------------------------+
# (train_model pid=62148) 2026/01/11 21:47:30 INFO alembic.runtime.migration: Running upgrade  -> 451aebb31d03, add metric step
# (train_model pid=62148) 2026/01/11 21:47:30 INFO alembic.runtime.migration: Running upgrade 451aebb31d03 -> 90e64c465722, migrate user column to tags
# (train_model pid=62148) 2026/01/11 21:47:30 INFO alembic.runtime.migration: Running upgrade 90e64c465722 -> 181f10493468, allow nulls for metric values
# (train_model pid=62148) 2026/01/11 21:47:30 INFO alembic.runtime.migration: Running upgrade 181f10493468 -> df50e92ffc5e, Add Experiment Tags Table
# (train_model pid=62148) 2026/01/11 21:47:30 INFO alembic.runtime.migration: Running upgrade df50e92ffc5e -> 7ac759974ad8, Update run tags with larger limit
# (train_model pid=62148) 2026/01/11 21:47:30 INFO alembic.runtime.migration: Running upgrade 7ac759974ad8 -> 89d4b8295536, create latest metrics table
# (train_model pid=62148) 2026/01/11 21:47:30 INFO alembic.runtime.migration: Running upgrade 89d4b8295536 -> 2b4d017a5e9b, add model registry tables to db
# (train_model pid=62148) 2026/01/11 21:47:30 INFO alembic.runtime.migration: Running upgrade 2b4d017a5e9b -> cfd24bdc0731, Update run status constraint with killed
# (train_model pid=62148) 2026/01/11 21:47:30 INFO alembic.runtime.migration: Running upgrade cfd24bdc0731 -> 0a8213491aaa, drop_duplicate_killed_constraint
# (train_model pid=62148) 2026/01/11 21:47:30 INFO alembic.runtime.migration: Running upgrade 0a8213491aaa -> 728d730b5ebd, add registered model tags table
# (train_model pid=62148) 2026/01/11 21:47:30 INFO alembic.runtime.migration: Running upgrade 728d730b5ebd -> 27a6a02d2cf1, add model version tags table
# (train_model pid=62148) 2026/01/11 21:47:30 INFO alembic.runtime.migration: Running upgrade 27a6a02d2cf1 -> 84291f40a231, add run_link to model_version
# (train_model pid=62148) 2026/01/11 21:47:30 INFO alembic.runtime.migration: Running upgrade 84291f40a231 -> a8c4a736bde6, allow nulls for run_id
# (train_model pid=62148) 2026/01/11 21:47:30 INFO alembic.runtime.migration: Running upgrade a8c4a736bde6 -> 39d1c3be5f05, add_is_nan_constraint_for_metrics_tables_if_necessary
# (train_model pid=62148) 2026/01/11 21:47:30 INFO alembic.runtime.migration: Running upgrade 39d1c3be5f05 -> c48cb773bb87, reset_default_value_for_is_nan_in_metrics_table_for_mysql
# (train_model pid=62148) 2026/01/11 21:47:30 INFO alembic.runtime.migration: Running upgrade c48cb773bb87 -> bd07f7e963c5, create index on run_uuid
# (train_model pid=62148) 2026/01/11 21:47:30 INFO alembic.runtime.migration: Running upgrade bd07f7e963c5 -> 0c779009ac13, add deleted_time field to runs table
# (train_model pid=62148) 2026/01/11 21:47:30 INFO alembic.runtime.migration: Running upgrade 0c779009ac13 -> cc1f77228345, change param value length to 500
# (train_model pid=62148) 2026/01/11 21:47:31 INFO alembic.runtime.migration: Running upgrade cc1f77228345 -> 97727af70f4d, Add creation_time and last_update_time to experiments table
# (train_model pid=62148) 2026/01/11 21:47:31 INFO alembic.runtime.migration: Running upgrade 97727af70f4d -> 3500859a5d39, Add Model Aliases table
# (train_model pid=62148) 2026/01/11 21:47:31 INFO alembic.runtime.migration: Running upgrade 3500859a5d39 -> 7f2a7d5fae7d, add datasets inputs input_tags tables
# (train_model pid=62148) 2026/01/11 21:47:31 INFO alembic.runtime.migration: Running upgrade 7f2a7d5fae7d -> 2d6e25af4d3e, increase max param val length from 500 to 8000
# (train_model pid=62148) 2026/01/11 21:47:31 INFO alembic.runtime.migration: Running upgrade 2d6e25af4d3e -> acf3f17fdcc7, add storage location field to model versions
# (train_model pid=62148) 2026/01/11 21:47:31 INFO alembic.runtime.migration: Running upgrade acf3f17fdcc7 -> 867495a8f9d4, add trace tables
# (train_model pid=62148) 2026/01/11 21:47:31 INFO alembic.runtime.migration: Running upgrade 867495a8f9d4 -> 5b0e9adcef9c, add cascade deletion to trace tables foreign keys
# (train_model pid=62148) 2026/01/11 21:47:31 INFO alembic.runtime.migration: Running upgrade 5b0e9adcef9c -> 4465047574b1, increase max dataset schema size
# (train_model pid=62148) 2026/01/11 21:47:31 INFO alembic.runtime.migration: Running upgrade 4465047574b1 -> f5a4f2784254, increase run tag value limit to 8000
# (train_model pid=62148) 2026/01/11 21:47:31 INFO alembic.runtime.migration: Running upgrade f5a4f2784254 -> 0584bdc529eb, add cascading deletion to datasets from experiments
# (train_model pid=62148) 2026/01/11 21:47:31 INFO alembic.runtime.migration: Running upgrade 0584bdc529eb -> 400f98739977, add logged model tables
# (train_model pid=62148) 2026/01/11 21:47:31 INFO alembic.runtime.migration: Running upgrade 400f98739977 -> 6953534de441, add step to inputs table
# (train_model pid=62148) 2026/01/11 21:47:31 INFO alembic.runtime.migration: Running upgrade 6953534de441 -> bda7b8c39065, increase_model_version_tag_value_limit
# (train_model pid=62148) 2026/01/11 21:47:31 INFO alembic.runtime.migration: Running upgrade bda7b8c39065 -> cbc13b556ace, add V3 trace schema columns
# (train_model pid=62148) 2026/01/11 21:47:31 INFO alembic.runtime.migration: Running upgrade cbc13b556ace -> 770bee3ae1dd, add assessments table
# (train_model pid=62148) 2026/01/11 21:47:31 INFO alembic.runtime.migration: Running upgrade 770bee3ae1dd -> a1b2c3d4e5f6, add spans table
# (train_model pid=62148) 2026/01/11 21:47:32 INFO alembic.runtime.migration: Running upgrade a1b2c3d4e5f6 -> de4033877273, create entity_associations table
# (train_model pid=62148) 2026/01/11 21:47:32 INFO alembic.runtime.migration: Running upgrade de4033877273 -> 1a0cddfcaa16, Add webhooks and webhook_events tables
# (train_model pid=62148) 2026/01/11 21:47:32 INFO alembic.runtime.migration: Running upgrade 1a0cddfcaa16 -> 534353b11cbc, add scorer tables
# (train_model pid=62148) 2026/01/11 21:47:32 INFO alembic.runtime.migration: Running upgrade 534353b11cbc -> 71994744cf8e, add evaluation datasets
# (train_model pid=62148) 2026/01/11 21:47:32 INFO alembic.runtime.migration: Running upgrade 71994744cf8e -> 3da73c924c2f, add outputs to dataset record
# (train_model pid=62148) 2026/01/11 21:47:32 INFO alembic.runtime.migration: Running upgrade 3da73c924c2f -> bf29a5ff90ea, add jobs table
# (train_model pid=62148) 2026/01/11 21:47:32 INFO alembic.runtime.migration: Running upgrade bf29a5ff90ea -> 1bd49d398cd23, add secrets tables
# Trial status: 2 RUNNING | 8 PENDING
# Current time: 2026-01-11 21:47:33. Total running time: 30s
# Logical resource usage: 2.0/2 CPUs, 0/0 GPUs
# +-----------------------------------------------------------------------------------------+
# | Trial name                status       n_estimators     max_depth     min_samples_split |
# +-----------------------------------------------------------------------------------------+
# | train_model_108ae_00000   RUNNING               161            19                     8 |
# | train_model_108ae_00001   RUNNING               139            19                     7 |
# | train_model_108ae_00002   PENDING               120             2                     9 |
# | train_model_108ae_00003   PENDING               438            18                     6 |
# | train_model_108ae_00004   PENDING               113            13                     8 |
# | train_model_108ae_00005   PENDING               159            11                     8 |
# | train_model_108ae_00006   PENDING               457            12                     4 |
# | train_model_108ae_00007   PENDING               389            13                     3 |
# | train_model_108ae_00008   PENDING               149             6                     6 |
# | train_model_108ae_00009   PENDING               155            16                     6 |
# +-----------------------------------------------------------------------------------------+
# (train_model pid=62148) 2026/01/11 21:47:33 INFO mlflow.tracking.fluent: Experiment with name 'Diabetes_Distributed_tuning' does not exist. Creating a new experiment.
# Trial train_model_108ae_00000 completed after 1 iterations at 2026-01-11 21:47:34. Total running time: 31s
# +--------------------------------------------------+
# | Trial train_model_108ae_00000 result             |
# +--------------------------------------------------+
# | checkpoint_dir_name                              |
# | time_this_iter_s                          6.1198 |
# | time_total_s                              6.1198 |
# | training_iteration                             1 |
# | rmse                                     59.0551 |
# +--------------------------------------------------+
#
# Trial train_model_108ae_00001 completed after 1 iterations at 2026-01-11 21:47:36. Total running time: 33s
# +--------------------------------------------------+
# | Trial train_model_108ae_00001 result             |
# +--------------------------------------------------+
# | checkpoint_dir_name                              |
# | time_this_iter_s                         6.40005 |
# | time_total_s                             6.40005 |
# | training_iteration                             1 |
# | rmse                                     57.4511 |
# +--------------------------------------------------+
#
# Trial train_model_108ae_00002 started with configuration:
# +----------------------------------------------+
# | Trial train_model_108ae_00002 config         |
# +----------------------------------------------+
# | max_depth                                  2 |
# | min_samples_split                          9 |
# | n_estimators                             120 |
# +----------------------------------------------+
#
# Trial train_model_108ae_00003 started with configuration:
# +----------------------------------------------+
# | Trial train_model_108ae_00003 config         |
# +----------------------------------------------+
# | max_depth                                 18 |
# | min_samples_split                          6 |
# | n_estimators                             438 |
# +----------------------------------------------+
# (train_model pid=62429) 2026/01/11 21:47:58 INFO mlflow.store.db.utils: Creating initial MLflow database tables... [repeated 2x across cluster]
# (train_model pid=62192) 2026/01/11 21:47:31 INFO mlflow.store.db.utils: Updating database tables
# (train_model pid=62192) 2026/01/11 21:47:34 INFO alembic.runtime.migration: Context impl SQLiteImpl. [repeated 3x across cluster]
# (train_model pid=62192) 2026/01/11 21:47:34 INFO alembic.runtime.migration: Will assume non-transactional DDL. [repeated 3x across cluster]
# (train_model pid=62192) 2026/01/11 21:47:31 INFO alembic.runtime.migration: Running upgrade  -> 451aebb31d03, add metric step
# (train_model pid=62192) 2026/01/11 21:47:31 INFO alembic.runtime.migration: Running upgrade 451aebb31d03 -> 90e64c465722, migrate user column to tags
# (train_model pid=62192) 2026/01/11 21:47:31 INFO alembic.runtime.migration: Running upgrade 90e64c465722 -> 181f10493468, allow nulls for metric values
# (train_model pid=62192) 2026/01/11 21:47:31 INFO alembic.runtime.migration: Running upgrade 181f10493468 -> df50e92ffc5e, Add Experiment Tags Table
# (train_model pid=62192) 2026/01/11 21:47:32 INFO alembic.runtime.migration: Running upgrade df50e92ffc5e -> 7ac759974ad8, Update run tags with larger limit
# (train_model pid=62192) 2026/01/11 21:47:32 INFO alembic.runtime.migration: Running upgrade 7ac759974ad8 -> 89d4b8295536, create latest metrics table
# (train_model pid=62192) 2026/01/11 21:47:32 INFO alembic.runtime.migration: Running upgrade 89d4b8295536 -> 2b4d017a5e9b, add model registry tables to db
# (train_model pid=62192) 2026/01/11 21:47:32 INFO alembic.runtime.migration: Running upgrade 2b4d017a5e9b -> cfd24bdc0731, Update run status constraint with killed
# (train_model pid=62192) 2026/01/11 21:47:32 INFO alembic.runtime.migration: Running upgrade cfd24bdc0731 -> 0a8213491aaa, drop_duplicate_killed_constraint
# (train_model pid=62192) 2026/01/11 21:47:32 INFO alembic.runtime.migration: Running upgrade 0a8213491aaa -> 728d730b5ebd, add registered model tags table
# (train_model pid=62192) 2026/01/11 21:47:32 INFO alembic.runtime.migration: Running upgrade 728d730b5ebd -> 27a6a02d2cf1, add model version tags table
# (train_model pid=62192) 2026/01/11 21:47:32 INFO alembic.runtime.migration: Running upgrade 27a6a02d2cf1 -> 84291f40a231, add run_link to model_version
# (train_model pid=62192) 2026/01/11 21:47:32 INFO alembic.runtime.migration: Running upgrade 84291f40a231 -> a8c4a736bde6, allow nulls for run_id
# (train_model pid=62192) 2026/01/11 21:47:32 INFO alembic.runtime.migration: Running upgrade a8c4a736bde6 -> 39d1c3be5f05, add_is_nan_constraint_for_metrics_tables_if_necessary
# (train_model pid=62192) 2026/01/11 21:47:32 INFO alembic.runtime.migration: Running upgrade 39d1c3be5f05 -> c48cb773bb87, reset_default_value_for_is_nan_in_metrics_table_for_mysql
# (train_model pid=62192) 2026/01/11 21:47:32 INFO alembic.runtime.migration: Running upgrade c48cb773bb87 -> bd07f7e963c5, create index on run_uuid
# (train_model pid=62192) 2026/01/11 21:47:32 INFO alembic.runtime.migration: Running upgrade bd07f7e963c5 -> 0c779009ac13, add deleted_time field to runs table
# (train_model pid=62192) 2026/01/11 21:47:32 INFO alembic.runtime.migration: Running upgrade 0c779009ac13 -> cc1f77228345, change param value length to 500
# (train_model pid=62192) 2026/01/11 21:47:32 INFO alembic.runtime.migration: Running upgrade cc1f77228345 -> 97727af70f4d, Add creation_time and last_update_time to experiments table
# (train_model pid=62192) 2026/01/11 21:47:32 INFO alembic.runtime.migration: Running upgrade 97727af70f4d -> 3500859a5d39, Add Model Aliases table
# (train_model pid=62192) 2026/01/11 21:47:32 INFO alembic.runtime.migration: Running upgrade 3500859a5d39 -> 7f2a7d5fae7d, add datasets inputs input_tags tables
# (train_model pid=62192) 2026/01/11 21:47:33 INFO alembic.runtime.migration: Running upgrade 7f2a7d5fae7d -> 2d6e25af4d3e, increase max param val length from 500 to 8000
# (train_model pid=62192) 2026/01/11 21:47:33 INFO alembic.runtime.migration: Running upgrade 2d6e25af4d3e -> acf3f17fdcc7, add storage location field to model versions
# (train_model pid=62192) 2026/01/11 21:47:33 INFO alembic.runtime.migration: Running upgrade acf3f17fdcc7 -> 867495a8f9d4, add trace tables
# (train_model pid=62192) 2026/01/11 21:47:33 INFO alembic.runtime.migration: Running upgrade 867495a8f9d4 -> 5b0e9adcef9c, add cascade deletion to trace tables foreign keys
# (train_model pid=62192) 2026/01/11 21:47:33 INFO alembic.runtime.migration: Running upgrade 5b0e9adcef9c -> 4465047574b1, increase max dataset schema size
# (train_model pid=62192) 2026/01/11 21:47:33 INFO alembic.runtime.migration: Running upgrade 4465047574b1 -> f5a4f2784254, increase run tag value limit to 8000
# (train_model pid=62192) 2026/01/11 21:47:33 INFO alembic.runtime.migration: Running upgrade f5a4f2784254 -> 0584bdc529eb, add cascading deletion to datasets from experiments
# (train_model pid=62192) 2026/01/11 21:47:33 INFO alembic.runtime.migration: Running upgrade 0584bdc529eb -> 400f98739977, add logged model tables
# (train_model pid=62192) 2026/01/11 21:47:33 INFO alembic.runtime.migration: Running upgrade 400f98739977 -> 6953534de441, add step to inputs table
# (train_model pid=62192) 2026/01/11 21:47:33 INFO alembic.runtime.migration: Running upgrade 6953534de441 -> bda7b8c39065, increase_model_version_tag_value_limit
# (train_model pid=62192) 2026/01/11 21:47:33 INFO alembic.runtime.migration: Running upgrade bda7b8c39065 -> cbc13b556ace, add V3 trace schema columns
# (train_model pid=62192) 2026/01/11 21:47:33 INFO alembic.runtime.migration: Running upgrade cbc13b556ace -> 770bee3ae1dd, add assessments table
# (train_model pid=62192) 2026/01/11 21:47:33 INFO alembic.runtime.migration: Running upgrade 770bee3ae1dd -> a1b2c3d4e5f6, add spans table
# (train_model pid=62192) 2026/01/11 21:47:33 INFO alembic.runtime.migration: Running upgrade a1b2c3d4e5f6 -> de4033877273, create entity_associations table
# (train_model pid=62192) 2026/01/11 21:47:33 INFO alembic.runtime.migration: Running upgrade de4033877273 -> 1a0cddfcaa16, Add webhooks and webhook_events tables
# (train_model pid=62192) 2026/01/11 21:47:34 INFO alembic.runtime.migration: Running upgrade 1a0cddfcaa16 -> 534353b11cbc, add scorer tables
# (train_model pid=62192) 2026/01/11 21:47:34 INFO alembic.runtime.migration: Running upgrade 534353b11cbc -> 71994744cf8e, add evaluation datasets
# (train_model pid=62192) 2026/01/11 21:47:34 INFO alembic.runtime.migration: Running upgrade 71994744cf8e -> 3da73c924c2f, add outputs to dataset record
# (train_model pid=62192) 2026/01/11 21:47:34 INFO alembic.runtime.migration: Running upgrade 3da73c924c2f -> bf29a5ff90ea, add jobs table
# (train_model pid=62192) 2026/01/11 21:47:34 INFO alembic.runtime.migration: Running upgrade bf29a5ff90ea -> 1bd49d398cd23, add secrets tables
# (train_model pid=62192) 2026/01/11 21:47:34 INFO mlflow.tracking.fluent: Experiment with name 'Diabetes_Distributed_tuning' does not exist. Creating a new experiment.
# (train_model pid=62429) 2026/01/11 21:47:58 INFO mlflow.store.db.utils: Updating database tables
# (train_model pid=62429) 2026/01/11 21:47:59 INFO alembic.runtime.migration: Running upgrade  -> 451aebb31d03, add metric step
# (train_model pid=62429) 2026/01/11 21:47:59 INFO alembic.runtime.migration: Running upgrade 451aebb31d03 -> 90e64c465722, migrate user column to tags
# (train_model pid=62429) 2026/01/11 21:47:59 INFO alembic.runtime.migration: Running upgrade 90e64c465722 -> 181f10493468, allow nulls for metric values
# (train_model pid=62429) 2026/01/11 21:47:59 INFO alembic.runtime.migration: Running upgrade 181f10493468 -> df50e92ffc5e, Add Experiment Tags Table
# (train_model pid=62429) 2026/01/11 21:47:59 INFO alembic.runtime.migration: Running upgrade df50e92ffc5e -> 7ac759974ad8, Update run tags with larger limit
# (train_model pid=62429) 2026/01/11 21:47:59 INFO alembic.runtime.migration: Running upgrade 7ac759974ad8 -> 89d4b8295536, create latest metrics table
# (train_model pid=62429) 2026/01/11 21:47:59 INFO alembic.runtime.migration: Running upgrade 89d4b8295536 -> 2b4d017a5e9b, add model registry tables to db
# (train_model pid=62429) 2026/01/11 21:47:59 INFO alembic.runtime.migration: Running upgrade 2b4d017a5e9b -> cfd24bdc0731, Update run status constraint with killed
# (train_model pid=62429) 2026/01/11 21:47:59 INFO alembic.runtime.migration: Running upgrade cfd24bdc0731 -> 0a8213491aaa, drop_duplicate_killed_constraint
# (train_model pid=62429) 2026/01/11 21:47:59 INFO alembic.runtime.migration: Running upgrade 0a8213491aaa -> 728d730b5ebd, add registered model tags table
# (train_model pid=62429) 2026/01/11 21:47:59 INFO alembic.runtime.migration: Running upgrade 728d730b5ebd -> 27a6a02d2cf1, add model version tags table
# (train_model pid=62429) 2026/01/11 21:47:59 INFO alembic.runtime.migration: Running upgrade 27a6a02d2cf1 -> 84291f40a231, add run_link to model_version
# (train_model pid=62429) 2026/01/11 21:47:59 INFO alembic.runtime.migration: Running upgrade 84291f40a231 -> a8c4a736bde6, allow nulls for run_id
# (train_model pid=62429) 2026/01/11 21:47:59 INFO alembic.runtime.migration: Running upgrade a8c4a736bde6 -> 39d1c3be5f05, add_is_nan_constraint_for_metrics_tables_if_necessary
# (train_model pid=62429) 2026/01/11 21:47:59 INFO alembic.runtime.migration: Running upgrade 39d1c3be5f05 -> c48cb773bb87, reset_default_value_for_is_nan_in_metrics_table_for_mysql
# (train_model pid=62429) 2026/01/11 21:47:59 INFO alembic.runtime.migration: Running upgrade c48cb773bb87 -> bd07f7e963c5, create index on run_uuid
# (train_model pid=62429) 2026/01/11 21:47:59 INFO alembic.runtime.migration: Running upgrade bd07f7e963c5 -> 0c779009ac13, add deleted_time field to runs table
# (train_model pid=62429) 2026/01/11 21:47:59 INFO alembic.runtime.migration: Running upgrade 0c779009ac13 -> cc1f77228345, change param value length to 500
# (train_model pid=62429) 2026/01/11 21:47:59 INFO alembic.runtime.migration: Running upgrade cc1f77228345 -> 97727af70f4d, Add creation_time and last_update_time to experiments table
# (train_model pid=62429) 2026/01/11 21:48:00 INFO alembic.runtime.migration: Running upgrade 97727af70f4d -> 3500859a5d39, Add Model Aliases table
# (train_model pid=62429) 2026/01/11 21:48:00 INFO alembic.runtime.migration: Running upgrade 3500859a5d39 -> 7f2a7d5fae7d, add datasets inputs input_tags tables
# (train_model pid=62429) 2026/01/11 21:48:00 INFO alembic.runtime.migration: Running upgrade 7f2a7d5fae7d -> 2d6e25af4d3e, increase max param val length from 500 to 8000
# (train_model pid=62429) 2026/01/11 21:48:00 INFO alembic.runtime.migration: Running upgrade 2d6e25af4d3e -> acf3f17fdcc7, add storage location field to model versions
# (train_model pid=62429) 2026/01/11 21:48:00 INFO alembic.runtime.migration: Running upgrade acf3f17fdcc7 -> 867495a8f9d4, add trace tables
# (train_model pid=62429) 2026/01/11 21:48:00 INFO alembic.runtime.migration: Running upgrade 867495a8f9d4 -> 5b0e9adcef9c, add cascade deletion to trace tables foreign keys
# (train_model pid=62429) 2026/01/11 21:48:00 INFO alembic.runtime.migration: Running upgrade 5b0e9adcef9c -> 4465047574b1, increase max dataset schema size
# (train_model pid=62429) 2026/01/11 21:48:00 INFO alembic.runtime.migration: Running upgrade 4465047574b1 -> f5a4f2784254, increase run tag value limit to 8000
# (train_model pid=62429) 2026/01/11 21:48:00 INFO alembic.runtime.migration: Running upgrade f5a4f2784254 -> 0584bdc529eb, add cascading deletion to datasets from experiments
# (train_model pid=62429) 2026/01/11 21:48:00 INFO alembic.runtime.migration: Running upgrade 0584bdc529eb -> 400f98739977, add logged model tables
# (train_model pid=62429) 2026/01/11 21:48:00 INFO alembic.runtime.migration: Running upgrade 400f98739977 -> 6953534de441, add step to inputs table
# (train_model pid=62429) 2026/01/11 21:48:00 INFO alembic.runtime.migration: Running upgrade 6953534de441 -> bda7b8c39065, increase_model_version_tag_value_limit
# (train_model pid=62429) 2026/01/11 21:48:00 INFO alembic.runtime.migration: Running upgrade bda7b8c39065 -> cbc13b556ace, add V3 trace schema columns
# (train_model pid=62429) 2026/01/11 21:48:00 INFO alembic.runtime.migration: Running upgrade cbc13b556ace -> 770bee3ae1dd, add assessments table
# (train_model pid=62429) 2026/01/11 21:48:01 INFO alembic.runtime.migration: Running upgrade 770bee3ae1dd -> a1b2c3d4e5f6, add spans table
# (train_model pid=62429) 2026/01/11 21:48:01 INFO alembic.runtime.migration: Running upgrade a1b2c3d4e5f6 -> de4033877273, create entity_associations table
# (train_model pid=62429) 2026/01/11 21:48:01 INFO alembic.runtime.migration: Running upgrade de4033877273 -> 1a0cddfcaa16, Add webhooks and webhook_events tables
# (train_model pid=62429) 2026/01/11 21:48:01 INFO alembic.runtime.migration: Running upgrade 1a0cddfcaa16 -> 534353b11cbc, add scorer tables
# (train_model pid=62429) 2026/01/11 21:48:01 INFO alembic.runtime.migration: Running upgrade 534353b11cbc -> 71994744cf8e, add evaluation datasets
# (train_model pid=62429) 2026/01/11 21:48:02 INFO alembic.runtime.migration: Running upgrade 71994744cf8e -> 3da73c924c2f, add outputs to dataset record
# (train_model pid=62429) 2026/01/11 21:48:02 INFO alembic.runtime.migration: Running upgrade 3da73c924c2f -> bf29a5ff90ea, add jobs table
# (train_model pid=62429) 2026/01/11 21:48:02 INFO alembic.runtime.migration: Running upgrade bf29a5ff90ea -> 1bd49d398cd23, add secrets tables
# (train_model pid=62429) 2026/01/11 21:48:02 INFO mlflow.tracking.fluent: Experiment with name 'Diabetes_Distributed_tuning' does not exist. Creating a new experiment.
# Trial status: 2 TERMINATED | 2 RUNNING | 6 PENDING
# Current time: 2026-01-11 21:48:03. Total running time: 1min 0s
# Logical resource usage: 2.0/2 CPUs, 0/0 GPUs
# Current best trial: 108ae_00002 with rmse=56.214296467306326 and params={'n_estimators': 120, 'max_depth': 2, 'min_samples_split': 9}
# +---------------------------------------------------------------------------------------------------------------------------------+
# | Trial name                status         n_estimators     max_depth     min_samples_split     iter     total time (s)      rmse |
# +---------------------------------------------------------------------------------------------------------------------------------+
# | train_model_108ae_00002   RUNNING                 120             2                     9        1            6.86208   56.2143 |
# | train_model_108ae_00003   RUNNING                 438            18                     6                                       |
# | train_model_108ae_00000   TERMINATED              161            19                     8        1            6.1198    59.055  |
# | train_model_108ae_00001   TERMINATED              139            19                     7        1            6.40005   57.4512 |
# | train_model_108ae_00004   PENDING                 113            13                     8                                       |
# | train_model_108ae_00005   PENDING                 159            11                     8                                       |
# | train_model_108ae_00006   PENDING                 457            12                     4                                       |
# | train_model_108ae_00007   PENDING                 389            13                     3                                       |
# | train_model_108ae_00008   PENDING                 149             6                     6                                       |
# | train_model_108ae_00009   PENDING                 155            16                     6                                       |
# +---------------------------------------------------------------------------------------------------------------------------------+
#
# Trial train_model_108ae_00002 completed after 1 iterations at 2026-01-11 21:48:03. Total running time: 1min 0s
# +--------------------------------------------------+
# | Trial train_model_108ae_00002 result             |
# +--------------------------------------------------+
# | checkpoint_dir_name                              |
# | time_this_iter_s                         6.86208 |
# | time_total_s                             6.86208 |
# | training_iteration                             1 |
# | rmse                                     56.2143 |
# +--------------------------------------------------+
# (train_model pid=62468) 2026/01/11 21:48:00 INFO mlflow.store.db.utils: Creating initial MLflow database tables...
# (train_model pid=62468) 2026/01/11 21:48:03 INFO alembic.runtime.migration: Context impl SQLiteImpl. [repeated 4x across cluster]
# (train_model pid=62468) 2026/01/11 21:48:03 INFO alembic.runtime.migration: Will assume non-transactional DDL. [repeated 4x across cluster]
# Trial train_model_108ae_00003 completed after 1 iterations at 2026-01-11 21:48:08. Total running time: 1min 5s
# +--------------------------------------------------+
# | Trial train_model_108ae_00003 result             |
# +--------------------------------------------------+
# | checkpoint_dir_name                              |
# | time_this_iter_s                         9.74288 |
# | time_total_s                             9.74288 |
# | training_iteration                             1 |
# | rmse                                     48.2815 |
# +--------------------------------------------------+
#
# Trial train_model_108ae_00004 started with configuration:
# +----------------------------------------------+
# | Trial train_model_108ae_00004 config         |
# +----------------------------------------------+
# | max_depth                                 13 |
# | min_samples_split                          8 |
# | n_estimators                             113 |
# +----------------------------------------------+
#
# Trial train_model_108ae_00005 started with configuration:
# +----------------------------------------------+
# | Trial train_model_108ae_00005 config         |
# +----------------------------------------------+
# | max_depth                                 11 |
# | min_samples_split                          8 |
# | n_estimators                             159 |
# +----------------------------------------------+
# (train_model pid=62687) 2026/01/11 21:48:25 INFO mlflow.store.db.utils: Creating initial MLflow database tables...
# (train_model pid=62468) 2026/01/11 21:48:00 INFO mlflow.store.db.utils: Updating database tables
# (train_model pid=62468) 2026/01/11 21:48:00 INFO alembic.runtime.migration: Running upgrade  -> 451aebb31d03, add metric step
# (train_model pid=62468) 2026/01/11 21:48:00 INFO alembic.runtime.migration: Running upgrade 451aebb31d03 -> 90e64c465722, migrate user column to tags
# (train_model pid=62468) 2026/01/11 21:48:00 INFO alembic.runtime.migration: Running upgrade 90e64c465722 -> 181f10493468, allow nulls for metric values
# (train_model pid=62468) 2026/01/11 21:48:00 INFO alembic.runtime.migration: Running upgrade 181f10493468 -> df50e92ffc5e, Add Experiment Tags Table
# (train_model pid=62468) 2026/01/11 21:48:00 INFO alembic.runtime.migration: Running upgrade df50e92ffc5e -> 7ac759974ad8, Update run tags with larger limit
# (train_model pid=62468) 2026/01/11 21:48:00 INFO alembic.runtime.migration: Running upgrade 7ac759974ad8 -> 89d4b8295536, create latest metrics table
# (train_model pid=62468) 2026/01/11 21:48:01 INFO alembic.runtime.migration: Running upgrade 89d4b8295536 -> 2b4d017a5e9b, add model registry tables to db
# (train_model pid=62468) 2026/01/11 21:48:01 INFO alembic.runtime.migration: Running upgrade 2b4d017a5e9b -> cfd24bdc0731, Update run status constraint with killed
# (train_model pid=62468) 2026/01/11 21:48:01 INFO alembic.runtime.migration: Running upgrade cfd24bdc0731 -> 0a8213491aaa, drop_duplicate_killed_constraint
# (train_model pid=62468) 2026/01/11 21:48:01 INFO alembic.runtime.migration: Running upgrade 0a8213491aaa -> 728d730b5ebd, add registered model tags table
# (train_model pid=62468) 2026/01/11 21:48:01 INFO alembic.runtime.migration: Running upgrade 728d730b5ebd -> 27a6a02d2cf1, add model version tags table
# (train_model pid=62468) 2026/01/11 21:48:01 INFO alembic.runtime.migration: Running upgrade 27a6a02d2cf1 -> 84291f40a231, add run_link to model_version
# (train_model pid=62468) 2026/01/11 21:48:01 INFO alembic.runtime.migration: Running upgrade 84291f40a231 -> a8c4a736bde6, allow nulls for run_id
# (train_model pid=62468) 2026/01/11 21:48:01 INFO alembic.runtime.migration: Running upgrade a8c4a736bde6 -> 39d1c3be5f05, add_is_nan_constraint_for_metrics_tables_if_necessary
# (train_model pid=62468) 2026/01/11 21:48:01 INFO alembic.runtime.migration: Running upgrade 39d1c3be5f05 -> c48cb773bb87, reset_default_value_for_is_nan_in_metrics_table_for_mysql
# (train_model pid=62468) 2026/01/11 21:48:01 INFO alembic.runtime.migration: Running upgrade c48cb773bb87 -> bd07f7e963c5, create index on run_uuid
# (train_model pid=62468) 2026/01/11 21:48:01 INFO alembic.runtime.migration: Running upgrade bd07f7e963c5 -> 0c779009ac13, add deleted_time field to runs table
# (train_model pid=62468) 2026/01/11 21:48:01 INFO alembic.runtime.migration: Running upgrade 0c779009ac13 -> cc1f77228345, change param value length to 500
# (train_model pid=62468) 2026/01/11 21:48:01 INFO alembic.runtime.migration: Running upgrade cc1f77228345 -> 97727af70f4d, Add creation_time and last_update_time to experiments table
# (train_model pid=62468) 2026/01/11 21:48:01 INFO alembic.runtime.migration: Running upgrade 97727af70f4d -> 3500859a5d39, Add Model Aliases table
# (train_model pid=62468) 2026/01/11 21:48:01 INFO alembic.runtime.migration: Running upgrade 3500859a5d39 -> 7f2a7d5fae7d, add datasets inputs input_tags tables
# (train_model pid=62468) 2026/01/11 21:48:02 INFO alembic.runtime.migration: Running upgrade 7f2a7d5fae7d -> 2d6e25af4d3e, increase max param val length from 500 to 8000
# (train_model pid=62468) 2026/01/11 21:48:02 INFO alembic.runtime.migration: Running upgrade 2d6e25af4d3e -> acf3f17fdcc7, add storage location field to model versions
# (train_model pid=62468) 2026/01/11 21:48:02 INFO alembic.runtime.migration: Running upgrade acf3f17fdcc7 -> 867495a8f9d4, add trace tables
# (train_model pid=62468) 2026/01/11 21:48:02 INFO alembic.runtime.migration: Running upgrade 867495a8f9d4 -> 5b0e9adcef9c, add cascade deletion to trace tables foreign keys
# (train_model pid=62468) 2026/01/11 21:48:02 INFO alembic.runtime.migration: Running upgrade 5b0e9adcef9c -> 4465047574b1, increase max dataset schema size
# (train_model pid=62468) 2026/01/11 21:48:02 INFO alembic.runtime.migration: Running upgrade 4465047574b1 -> f5a4f2784254, increase run tag value limit to 8000
# (train_model pid=62468) 2026/01/11 21:48:02 INFO alembic.runtime.migration: Running upgrade f5a4f2784254 -> 0584bdc529eb, add cascading deletion to datasets from experiments
# (train_model pid=62468) 2026/01/11 21:48:02 INFO alembic.runtime.migration: Running upgrade 0584bdc529eb -> 400f98739977, add logged model tables
# (train_model pid=62468) 2026/01/11 21:48:02 INFO alembic.runtime.migration: Running upgrade 400f98739977 -> 6953534de441, add step to inputs table
# (train_model pid=62468) 2026/01/11 21:48:02 INFO alembic.runtime.migration: Running upgrade 6953534de441 -> bda7b8c39065, increase_model_version_tag_value_limit
# (train_model pid=62468) 2026/01/11 21:48:02 INFO alembic.runtime.migration: Running upgrade bda7b8c39065 -> cbc13b556ace, add V3 trace schema columns
# (train_model pid=62468) 2026/01/11 21:48:02 INFO alembic.runtime.migration: Running upgrade cbc13b556ace -> 770bee3ae1dd, add assessments table
# (train_model pid=62468) 2026/01/11 21:48:02 INFO alembic.runtime.migration: Running upgrade 770bee3ae1dd -> a1b2c3d4e5f6, add spans table
# (train_model pid=62468) 2026/01/11 21:48:03 INFO alembic.runtime.migration: Running upgrade a1b2c3d4e5f6 -> de4033877273, create entity_associations table
# (train_model pid=62468) 2026/01/11 21:48:03 INFO alembic.runtime.migration: Running upgrade de4033877273 -> 1a0cddfcaa16, Add webhooks and webhook_events tables
# (train_model pid=62468) 2026/01/11 21:48:03 INFO alembic.runtime.migration: Running upgrade 1a0cddfcaa16 -> 534353b11cbc, add scorer tables
# (train_model pid=62468) 2026/01/11 21:48:03 INFO alembic.runtime.migration: Running upgrade 534353b11cbc -> 71994744cf8e, add evaluation datasets
# (train_model pid=62468) 2026/01/11 21:48:03 INFO alembic.runtime.migration: Running upgrade 71994744cf8e -> 3da73c924c2f, add outputs to dataset record
# (train_model pid=62468) 2026/01/11 21:48:03 INFO alembic.runtime.migration: Running upgrade 3da73c924c2f -> bf29a5ff90ea, add jobs table
# (train_model pid=62468) 2026/01/11 21:48:03 INFO alembic.runtime.migration: Running upgrade bf29a5ff90ea -> 1bd49d398cd23, add secrets tables
# (train_model pid=62468) 2026/01/11 21:48:03 INFO mlflow.tracking.fluent: Experiment with name 'Diabetes_Distributed_tuning' does not exist. Creating a new experiment.
# (train_model pid=62687) 2026/01/11 21:48:25 INFO mlflow.store.db.utils: Updating database tables
# (train_model pid=62687) 2026/01/11 21:48:25 INFO alembic.runtime.migration: Context impl SQLiteImpl.
# (train_model pid=62687) 2026/01/11 21:48:25 INFO alembic.runtime.migration: Will assume non-transactional DDL.
# (train_model pid=62687) 2026/01/11 21:48:25 INFO alembic.runtime.migration: Running upgrade  -> 451aebb31d03, add metric step
# (train_model pid=62687) 2026/01/11 21:48:25 INFO alembic.runtime.migration: Running upgrade 451aebb31d03 -> 90e64c465722, migrate user column to tags
# (train_model pid=62687) 2026/01/11 21:48:25 INFO alembic.runtime.migration: Running upgrade 90e64c465722 -> 181f10493468, allow nulls for metric values
# (train_model pid=62687) 2026/01/11 21:48:26 INFO alembic.runtime.migration: Running upgrade 181f10493468 -> df50e92ffc5e, Add Experiment Tags Table
# (train_model pid=62687) 2026/01/11 21:48:26 INFO alembic.runtime.migration: Running upgrade df50e92ffc5e -> 7ac759974ad8, Update run tags with larger limit
# (train_model pid=62687) 2026/01/11 21:48:26 INFO alembic.runtime.migration: Running upgrade 7ac759974ad8 -> 89d4b8295536, create latest metrics table
# (train_model pid=62687) 2026/01/11 21:48:26 INFO alembic.runtime.migration: Running upgrade 89d4b8295536 -> 2b4d017a5e9b, add model registry tables to db
# (train_model pid=62687) 2026/01/11 21:48:26 INFO alembic.runtime.migration: Running upgrade 2b4d017a5e9b -> cfd24bdc0731, Update run status constraint with killed
# (train_model pid=62687) 2026/01/11 21:48:26 INFO alembic.runtime.migration: Running upgrade cfd24bdc0731 -> 0a8213491aaa, drop_duplicate_killed_constraint
# (train_model pid=62687) 2026/01/11 21:48:26 INFO alembic.runtime.migration: Running upgrade 0a8213491aaa -> 728d730b5ebd, add registered model tags table
# (train_model pid=62687) 2026/01/11 21:48:26 INFO alembic.runtime.migration: Running upgrade 728d730b5ebd -> 27a6a02d2cf1, add model version tags table
# (train_model pid=62687) 2026/01/11 21:48:26 INFO alembic.runtime.migration: Running upgrade 27a6a02d2cf1 -> 84291f40a231, add run_link to model_version
# (train_model pid=62687) 2026/01/11 21:48:26 INFO alembic.runtime.migration: Running upgrade 84291f40a231 -> a8c4a736bde6, allow nulls for run_id
# (train_model pid=62687) 2026/01/11 21:48:26 INFO alembic.runtime.migration: Running upgrade a8c4a736bde6 -> 39d1c3be5f05, add_is_nan_constraint_for_metrics_tables_if_necessary
# (train_model pid=62687) 2026/01/11 21:48:26 INFO alembic.runtime.migration: Running upgrade 39d1c3be5f05 -> c48cb773bb87, reset_default_value_for_is_nan_in_metrics_table_for_mysql
# (train_model pid=62687) 2026/01/11 21:48:26 INFO alembic.runtime.migration: Running upgrade c48cb773bb87 -> bd07f7e963c5, create index on run_uuid
# (train_model pid=62687) 2026/01/11 21:48:26 INFO alembic.runtime.migration: Running upgrade bd07f7e963c5 -> 0c779009ac13, add deleted_time field to runs table
# (train_model pid=62687) 2026/01/11 21:48:26 INFO alembic.runtime.migration: Running upgrade 0c779009ac13 -> cc1f77228345, change param value length to 500
# (train_model pid=62687) 2026/01/11 21:48:27 INFO alembic.runtime.migration: Running upgrade cc1f77228345 -> 97727af70f4d, Add creation_time and last_update_time to experiments table
# (train_model pid=62687) 2026/01/11 21:48:27 INFO alembic.runtime.migration: Running upgrade 97727af70f4d -> 3500859a5d39, Add Model Aliases table
# (train_model pid=62687) 2026/01/11 21:48:27 INFO alembic.runtime.migration: Running upgrade 3500859a5d39 -> 7f2a7d5fae7d, add datasets inputs input_tags tables
# (train_model pid=62687) 2026/01/11 21:48:27 INFO alembic.runtime.migration: Running upgrade 7f2a7d5fae7d -> 2d6e25af4d3e, increase max param val length from 500 to 8000
# (train_model pid=62687) 2026/01/11 21:48:27 INFO alembic.runtime.migration: Running upgrade 2d6e25af4d3e -> acf3f17fdcc7, add storage location field to model versions
# (train_model pid=62687) 2026/01/11 21:48:27 INFO alembic.runtime.migration: Running upgrade acf3f17fdcc7 -> 867495a8f9d4, add trace tables
# (train_model pid=62687) 2026/01/11 21:48:27 INFO alembic.runtime.migration: Running upgrade 867495a8f9d4 -> 5b0e9adcef9c, add cascade deletion to trace tables foreign keys
# (train_model pid=62687) 2026/01/11 21:48:27 INFO alembic.runtime.migration: Running upgrade 5b0e9adcef9c -> 4465047574b1, increase max dataset schema size
# (train_model pid=62687) 2026/01/11 21:48:27 INFO alembic.runtime.migration: Running upgrade 4465047574b1 -> f5a4f2784254, increase run tag value limit to 8000
# (train_model pid=62687) 2026/01/11 21:48:27 INFO alembic.runtime.migration: Running upgrade f5a4f2784254 -> 0584bdc529eb, add cascading deletion to datasets from experiments
# (train_model pid=62687) 2026/01/11 21:48:27 INFO alembic.runtime.migration: Running upgrade 0584bdc529eb -> 400f98739977, add logged model tables
# (train_model pid=62687) 2026/01/11 21:48:28 INFO alembic.runtime.migration: Running upgrade 400f98739977 -> 6953534de441, add step to inputs table
# (train_model pid=62687) 2026/01/11 21:48:28 INFO alembic.runtime.migration: Running upgrade 6953534de441 -> bda7b8c39065, increase_model_version_tag_value_limit
# (train_model pid=62687) 2026/01/11 21:48:28 INFO alembic.runtime.migration: Running upgrade bda7b8c39065 -> cbc13b556ace, add V3 trace schema columns
# (train_model pid=62687) 2026/01/11 21:48:28 INFO alembic.runtime.migration: Running upgrade cbc13b556ace -> 770bee3ae1dd, add assessments table
# (train_model pid=62687) 2026/01/11 21:48:28 INFO alembic.runtime.migration: Running upgrade 770bee3ae1dd -> a1b2c3d4e5f6, add spans table
# (train_model pid=62687) 2026/01/11 21:48:28 INFO alembic.runtime.migration: Running upgrade a1b2c3d4e5f6 -> de4033877273, create entity_associations table
# (train_model pid=62687) 2026/01/11 21:48:28 INFO alembic.runtime.migration: Running upgrade de4033877273 -> 1a0cddfcaa16, Add webhooks and webhook_events tables
# (train_model pid=62687) 2026/01/11 21:48:28 INFO alembic.runtime.migration: Running upgrade 1a0cddfcaa16 -> 534353b11cbc, add scorer tables
# (train_model pid=62687) 2026/01/11 21:48:29 INFO alembic.runtime.migration: Running upgrade 534353b11cbc -> 71994744cf8e, add evaluation datasets
# (train_model pid=62687) 2026/01/11 21:48:29 INFO alembic.runtime.migration: Running upgrade 71994744cf8e -> 3da73c924c2f, add outputs to dataset record
# (train_model pid=62687) 2026/01/11 21:48:29 INFO alembic.runtime.migration: Running upgrade 3da73c924c2f -> bf29a5ff90ea, add jobs table
# (train_model pid=62687) 2026/01/11 21:48:29 INFO alembic.runtime.migration: Running upgrade bf29a5ff90ea -> 1bd49d398cd23, add secrets tables
# (train_model pid=62687) 2026/01/11 21:48:30 INFO mlflow.tracking.fluent: Experiment with name 'Diabetes_Distributed_tuning' does not exist. Creating a new experiment.
# (train_model pid=62696) 2026/01/11 21:48:26 INFO mlflow.store.db.utils: Creating initial MLflow database tables...
# (train_model pid=62696) 2026/01/11 21:48:26 INFO mlflow.store.db.utils: Updating database tables
# (train_model pid=62687) 2026/01/11 21:48:30 INFO alembic.runtime.migration: Context impl SQLiteImpl. [repeated 2x across cluster]
# (train_model pid=62687) 2026/01/11 21:48:30 INFO alembic.runtime.migration: Will assume non-transactional DDL. [repeated 2x across cluster]
# (train_model pid=62696) 2026/01/11 21:48:26 INFO alembic.runtime.migration: Running upgrade  -> 451aebb31d03, add metric step
# (train_model pid=62696) 2026/01/11 21:48:27 INFO alembic.runtime.migration: Running upgrade 451aebb31d03 -> 90e64c465722, migrate user column to tags
# (train_model pid=62696) 2026/01/11 21:48:27 INFO alembic.runtime.migration: Running upgrade 90e64c465722 -> 181f10493468, allow nulls for metric values
# (train_model pid=62696) 2026/01/11 21:48:27 INFO alembic.runtime.migration: Running upgrade 181f10493468 -> df50e92ffc5e, Add Experiment Tags Table
# (train_model pid=62696) 2026/01/11 21:48:27 INFO alembic.runtime.migration: Running upgrade df50e92ffc5e -> 7ac759974ad8, Update run tags with larger limit
# (train_model pid=62696) 2026/01/11 21:48:27 INFO alembic.runtime.migration: Running upgrade 7ac759974ad8 -> 89d4b8295536, create latest metrics table
# (train_model pid=62696) 2026/01/11 21:48:27 INFO alembic.runtime.migration: Running upgrade 89d4b8295536 -> 2b4d017a5e9b, add model registry tables to db
# Trial train_model_108ae_00004 completed after 1 iterations at 2026-01-11 21:48:32. Total running time: 1min 29s
# +--------------------------------------------------+
# | Trial train_model_108ae_00004 result             |
# +--------------------------------------------------+
# | checkpoint_dir_name                              |
# | time_this_iter_s                         8.36073 |
# | time_total_s                             8.36073 |
# | training_iteration                             1 |
# | rmse                                     60.0188 |
# +--------------------------------------------------+
#
# Trial train_model_108ae_00005 completed after 1 iterations at 2026-01-11 21:48:32. Total running time: 1min 29s
# +--------------------------------------------------+
# | Trial train_model_108ae_00005 result             |
# +--------------------------------------------------+
# | checkpoint_dir_name                              |
# | time_this_iter_s                         8.02774 |
# | time_total_s                             8.02774 |
# | training_iteration                             1 |
# | rmse                                     54.3941 |
# +--------------------------------------------------+
#
# Trial status: 6 TERMINATED | 4 PENDING
# Current time: 2026-01-11 21:48:33. Total running time: 1min 30s
# Logical resource usage: 0/2 CPUs, 0/0 GPUs
# Current best trial: 108ae_00003 with rmse=48.2814553526582 and params={'n_estimators': 438, 'max_depth': 18, 'min_samples_split': 6}
# ...
# (train_model pid=62959) 2026/01/11 21:48:56 INFO alembic.runtime.migration: Running upgrade cfd24bdc0731 -> 0a8213491aaa, drop_duplicate_killed_constraint
# (train_model pid=62959) 2026/01/11 21:48:56 INFO alembic.runtime.migration: Running upgrade 0a8213491aaa -> 728d730b5ebd, add registered model tags table
# (train_model pid=62959) 2026/01/11 21:48:56 INFO alembic.runtime.migration: Running upgrade 728d730b5ebd -> 27a6a02d2cf1, add model version tags table
# (train_model pid=62959) 2026/01/11 21:48:56 INFO alembic.runtime.migration: Running upgrade 27a6a02d2cf1 -> 84291f40a231, add run_link to model_version
# (train_model pid=62959) 2026/01/11 21:48:56 INFO alembic.runtime.migration: Running upgrade 84291f40a231 -> a8c4a736bde6, allow nulls for run_id
# (train_model pid=62959) 2026/01/11 21:48:57 INFO alembic.runtime.migration: Running upgrade a8c4a736bde6 -> 39d1c3be5f05, add_is_nan_constraint_for_metrics_tables_if_necessary
# (train_model pid=62959) 2026/01/11 21:48:57 INFO alembic.runtime.migration: Running upgrade 39d1c3be5f05 -> c48cb773bb87, reset_default_value_for_is_nan_in_metrics_table_for_mysql
# (train_model pid=62959) 2026/01/11 21:48:57 INFO alembic.runtime.migration: Running upgrade c48cb773bb87 -> bd07f7e963c5, create index on run_uuid
# (train_model pid=62959) 2026/01/11 21:48:57 INFO alembic.runtime.migration: Running upgrade bd07f7e963c5 -> 0c779009ac13, add deleted_time field to runs table
# (train_model pid=62959) 2026/01/11 21:48:57 INFO alembic.runtime.migration: Running upgrade 0c779009ac13 -> cc1f77228345, change param value length to 500
# (train_model pid=62959) 2026/01/11 21:48:57 INFO alembic.runtime.migration: Running upgrade cc1f77228345 -> 97727af70f4d, Add creation_time and last_update_time to experiments table
# (train_model pid=62959) 2026/01/11 21:48:57 INFO alembic.runtime.migration: Running upgrade 97727af70f4d -> 3500859a5d39, Add Model Aliases table
# (train_model pid=62959) 2026/01/11 21:48:57 INFO alembic.runtime.migration: Running upgrade 3500859a5d39 -> 7f2a7d5fae7d, add datasets inputs input_tags tables
# (train_model pid=62959) 2026/01/11 21:48:57 INFO alembic.runtime.migration: Running upgrade 7f2a7d5fae7d -> 2d6e25af4d3e, increase max param val length from 500 to 8000
# (train_model pid=62959) 2026/01/11 21:48:58 INFO alembic.runtime.migration: Running upgrade 2d6e25af4d3e -> acf3f17fdcc7, add storage location field to model versions
# (train_model pid=62959) 2026/01/11 21:48:58 INFO alembic.runtime.migration: Running upgrade acf3f17fdcc7 -> 867495a8f9d4, add trace tables
# (train_model pid=62959) 2026/01/11 21:48:58 INFO alembic.runtime.migration: Running upgrade 867495a8f9d4 -> 5b0e9adcef9c, add cascade deletion to trace tables foreign keys
# (train_model pid=62959) 2026/01/11 21:48:58 INFO alembic.runtime.migration: Running upgrade 5b0e9adcef9c -> 4465047574b1, increase max dataset schema size
# (train_model pid=62959) 2026/01/11 21:48:58 INFO alembic.runtime.migration: Running upgrade 4465047574b1 -> f5a4f2784254, increase run tag value limit to 8000
# (train_model pid=62959) 2026/01/11 21:48:58 INFO alembic.runtime.migration: Running upgrade f5a4f2784254 -> 0584bdc529eb, add cascading deletion to datasets from experiments
# (train_model pid=62959) 2026/01/11 21:48:58 INFO alembic.runtime.migration: Running upgrade 0584bdc529eb -> 400f98739977, add logged model tables
# (train_model pid=62959) 2026/01/11 21:48:58 INFO alembic.runtime.migration: Running upgrade 400f98739977 -> 6953534de441, add step to inputs table
# (train_model pid=62959) 2026/01/11 21:48:58 INFO alembic.runtime.migration: Running upgrade 6953534de441 -> bda7b8c39065, increase_model_version_tag_value_limit
# (train_model pid=62959) 2026/01/11 21:48:58 INFO alembic.runtime.migration: Running upgrade bda7b8c39065 -> cbc13b556ace, add V3 trace schema columns
# (train_model pid=62959) 2026/01/11 21:48:59 INFO alembic.runtime.migration: Running upgrade cbc13b556ace -> 770bee3ae1dd, add assessments table
# (train_model pid=62959) 2026/01/11 21:48:59 INFO alembic.runtime.migration: Running upgrade 770bee3ae1dd -> a1b2c3d4e5f6, add spans table
# (train_model pid=62959) 2026/01/11 21:48:59 INFO alembic.runtime.migration: Running upgrade a1b2c3d4e5f6 -> de4033877273, create entity_associations table
# (train_model pid=62959) 2026/01/11 21:48:59 INFO alembic.runtime.migration: Running upgrade de4033877273 -> 1a0cddfcaa16, Add webhooks and webhook_events tables
# (train_model pid=62959) 2026/01/11 21:48:59 INFO alembic.runtime.migration: Running upgrade 1a0cddfcaa16 -> 534353b11cbc, add scorer tables
# (train_model pid=62959) 2026/01/11 21:48:59 INFO alembic.runtime.migration: Running upgrade 534353b11cbc -> 71994744cf8e, add evaluation datasets
# (train_model pid=62959) 2026/01/11 21:49:00 INFO alembic.runtime.migration: Running upgrade 71994744cf8e -> 3da73c924c2f, add outputs to dataset record
# (train_model pid=62959) 2026/01/11 21:49:00 INFO alembic.runtime.migration: Running upgrade 3da73c924c2f -> bf29a5ff90ea, add jobs table
# (train_model pid=62959) 2026/01/11 21:49:00 INFO alembic.runtime.migration: Running upgrade bf29a5ff90ea -> 1bd49d398cd23, add secrets tables
# (train_model pid=62959) 2026/01/11 21:49:00 INFO mlflow.tracking.fluent: Experiment with name 'Diabetes_Distributed_tuning' does not exist. Creating a new experiment.
# (train_model pid=63234) 2026/01/11 21:49:27 INFO mlflow.store.db.utils: Updating database tables
# (train_model pid=63234) 2026/01/11 21:49:27 INFO alembic.runtime.migration: Running upgrade  -> 451aebb31d03, add metric step
# (train_model pid=63234) 2026/01/11 21:49:27 INFO alembic.runtime.migration: Running upgrade 451aebb31d03 -> 90e64c465722, migrate user column to tags
# (train_model pid=63234) 2026/01/11 21:49:27 INFO alembic.runtime.migration: Running upgrade 90e64c465722 -> 181f10493468, allow nulls for metric values
# (train_model pid=63234) 2026/01/11 21:49:28 INFO alembic.runtime.migration: Running upgrade 181f10493468 -> df50e92ffc5e, Add Experiment Tags Table
# (train_model pid=63234) 2026/01/11 21:49:28 INFO alembic.runtime.migration: Running upgrade df50e92ffc5e -> 7ac759974ad8, Update run tags with larger limit
# (train_model pid=63234) 2026/01/11 21:49:28 INFO alembic.runtime.migration: Running upgrade 7ac759974ad8 -> 89d4b8295536, create latest metrics table
# (train_model pid=63234) 2026/01/11 21:49:28 INFO alembic.runtime.migration: Running upgrade 89d4b8295536 -> 2b4d017a5e9b, add model registry tables to db
# (train_model pid=63234) 2026/01/11 21:49:28 INFO alembic.runtime.migration: Running upgrade 2b4d017a5e9b -> cfd24bdc0731, Update run status constraint with killed
# (train_model pid=63234) 2026/01/11 21:49:28 INFO alembic.runtime.migration: Running upgrade cfd24bdc0731 -> 0a8213491aaa, drop_duplicate_killed_constraint
# (train_model pid=63234) 2026/01/11 21:49:28 INFO alembic.runtime.migration: Running upgrade 0a8213491aaa -> 728d730b5ebd, add registered model tags table
# (train_model pid=63234) 2026/01/11 21:49:28 INFO alembic.runtime.migration: Running upgrade 728d730b5ebd -> 27a6a02d2cf1, add model version tags table
# (train_model pid=63234) 2026/01/11 21:49:28 INFO alembic.runtime.migration: Running upgrade 27a6a02d2cf1 -> 84291f40a231, add run_link to model_version
# (train_model pid=63234) 2026/01/11 21:49:28 INFO alembic.runtime.migration: Running upgrade 84291f40a231 -> a8c4a736bde6, allow nulls for run_id
# (train_model pid=63234) 2026/01/11 21:49:28 INFO alembic.runtime.migration: Running upgrade a8c4a736bde6 -> 39d1c3be5f05, add_is_nan_constraint_for_metrics_tables_if_necessary
# (train_model pid=63234) 2026/01/11 21:49:28 INFO alembic.runtime.migration: Running upgrade 39d1c3be5f05 -> c48cb773bb87, reset_default_value_for_is_nan_in_metrics_table_for_mysql
# (train_model pid=63234) 2026/01/11 21:49:28 INFO alembic.runtime.migration: Running upgrade c48cb773bb87 -> bd07f7e963c5, create index on run_uuid
# (train_model pid=63234) 2026/01/11 21:49:28 INFO alembic.runtime.migration: Running upgrade bd07f7e963c5 -> 0c779009ac13, add deleted_time field to runs table
# (train_model pid=63234) 2026/01/11 21:49:28 INFO alembic.runtime.migration: Running upgrade 0c779009ac13 -> cc1f77228345, change param value length to 500
# (train_model pid=63234) 2026/01/11 21:49:28 INFO alembic.runtime.migration: Running upgrade cc1f77228345 -> 97727af70f4d, Add creation_time and last_update_time to experiments table
# (train_model pid=63234) 2026/01/11 21:49:28 INFO alembic.runtime.migration: Running upgrade 97727af70f4d -> 3500859a5d39, Add Model Aliases table
# (train_model pid=63234) 2026/01/11 21:49:28 INFO alembic.runtime.migration: Running upgrade 3500859a5d39 -> 7f2a7d5fae7d, add datasets inputs input_tags tables
# (train_model pid=63234) 2026/01/11 21:49:29 INFO alembic.runtime.migration: Running upgrade 7f2a7d5fae7d -> 2d6e25af4d3e, increase max param val length from 500 to 8000
# (train_model pid=63234) 2026/01/11 21:49:29 INFO alembic.runtime.migration: Running upgrade 2d6e25af4d3e -> acf3f17fdcc7, add storage location field to model versions
# (train_model pid=63234) 2026/01/11 21:49:29 INFO alembic.runtime.migration: Running upgrade acf3f17fdcc7 -> 867495a8f9d4, add trace tables
# (train_model pid=63234) 2026/01/11 21:49:29 INFO alembic.runtime.migration: Running upgrade 867495a8f9d4 -> 5b0e9adcef9c, add cascade deletion to trace tables foreign keys
# (train_model pid=63234) 2026/01/11 21:49:29 INFO alembic.runtime.migration: Running upgrade 5b0e9adcef9c -> 4465047574b1, increase max dataset schema size
# (train_model pid=63234) 2026/01/11 21:49:29 INFO alembic.runtime.migration: Running upgrade 4465047574b1 -> f5a4f2784254, increase run tag value limit to 8000
# (train_model pid=63234) 2026/01/11 21:49:29 INFO alembic.runtime.migration: Running upgrade f5a4f2784254 -> 0584bdc529eb, add cascading deletion to datasets from experiments
# (train_model pid=63234) 2026/01/11 21:49:29 INFO alembic.runtime.migration: Running upgrade 0584bdc529eb -> 400f98739977, add logged model tables
# (train_model pid=63234) 2026/01/11 21:49:29 INFO alembic.runtime.migration: Running upgrade 400f98739977 -> 6953534de441, add step to inputs table
# (train_model pid=63234) 2026/01/11 21:49:29 INFO alembic.runtime.migration: Running upgrade 6953534de441 -> bda7b8c39065, increase_model_version_tag_value_limit
# (train_model pid=63234) 2026/01/11 21:49:29 INFO alembic.runtime.migration: Running upgrade bda7b8c39065 -> cbc13b556ace, add V3 trace schema columns
# (train_model pid=63234) 2026/01/11 21:49:29 INFO alembic.runtime.migration: Running upgrade cbc13b556ace -> 770bee3ae1dd, add assessments table
# (train_model pid=63234) 2026/01/11 21:49:29 INFO alembic.runtime.migration: Running upgrade 770bee3ae1dd -> a1b2c3d4e5f6, add spans table
# (train_model pid=63234) 2026/01/11 21:49:30 INFO alembic.runtime.migration: Running upgrade a1b2c3d4e5f6 -> de4033877273, create entity_associations table
# (train_model pid=63234) 2026/01/11 21:49:30 INFO alembic.runtime.migration: Running upgrade de4033877273 -> 1a0cddfcaa16, Add webhooks and webhook_events tables
# (train_model pid=63234) 2026/01/11 21:49:30 INFO alembic.runtime.migration: Running upgrade 1a0cddfcaa16 -> 534353b11cbc, add scorer tables
# (train_model pid=63234) 2026/01/11 21:49:30 INFO alembic.runtime.migration: Running upgrade 534353b11cbc -> 71994744cf8e, add evaluation datasets
# (train_model pid=63234) 2026/01/11 21:49:30 INFO alembic.runtime.migration: Running upgrade 71994744cf8e -> 3da73c924c2f, add outputs to dataset record
# (train_model pid=63234) 2026/01/11 21:49:30 INFO alembic.runtime.migration: Running upgrade 3da73c924c2f -> bf29a5ff90ea, add jobs table
# (train_model pid=63234) 2026/01/11 21:49:30 INFO alembic.runtime.migration: Running upgrade bf29a5ff90ea -> 1bd49d398cd23, add secrets tables
# (train_model pid=63234) 2026/01/11 21:49:31 INFO mlflow.tracking.fluent: Experiment with name 'Diabetes_Distributed_tuning' does not exist. Creating a new experiment.
# Trial train_model_108ae_00008 completed after 1 iterations at 2026-01-11 21:49:32. Total running time: 2min 29s
# +--------------------------------------------------+
# | Trial train_model_108ae_00008 result             |
# +--------------------------------------------------+
# | checkpoint_dir_name                              |
# | time_this_iter_s                         7.17649 |
# | time_total_s                             7.17649 |
# | training_iteration                             1 |
# | rmse                                     63.0379 |
# +--------------------------------------------------+
# 2026-01-11 21:49:32,591	INFO tune.py:1009 -- Wrote the latest version of all result files and experiment state to '/root/ray_results/train_model_2026-01-11_21-47-02' in 0.0128s.
# Trial train_model_108ae_00009 completed after 1 iterations at 2026-01-11 21:49:32. Total running time: 2min 29s
# +--------------------------------------------------+
# | Trial train_model_108ae_00009 result             |
# +--------------------------------------------------+
# | checkpoint_dir_name                              |
# | time_this_iter_s                         7.32038 |
# | time_total_s                             7.32038 |
# | training_iteration                             1 |
# | rmse                                     59.3184 |
# +--------------------------------------------------+
#
# Trial status: 10 TERMINATED
# Current time: 2026-01-11 21:49:32. Total running time: 2min 29s
# Logical resource usage: 1.0/2 CPUs, 0/0 GPUs
# Current best trial: 108ae_00003 with rmse=48.2814553526582 and params={'n_estimators': 438, 'max_depth': 18, 'min_samples_split': 6}
# +---------------------------------------------------------------------------------------------------------------------------------+
# | Trial name                status         n_estimators     max_depth     min_samples_split     iter     total time (s)      rmse |
# +---------------------------------------------------------------------------------------------------------------------------------+
# | train_model_108ae_00000   TERMINATED              161            19                     8        1            6.1198    59.055  |
# | train_model_108ae_00001   TERMINATED              139            19                     7        1            6.40005   57.4512 |
# | train_model_108ae_00002   TERMINATED              120             2                     9        1            6.86208   56.2143 |
# | train_model_108ae_00003   TERMINATED              438            18                     6        1            9.74288   48.2815 |
# | train_model_108ae_00004   TERMINATED              113            13                     8        1            8.36073   60.0188 |
# | train_model_108ae_00005   TERMINATED              159            11                     8        1            8.02774   54.3941 |
# | train_model_108ae_00006   TERMINATED              457            12                     4        1            9.77728   54.7528 |
# | train_model_108ae_00007   TERMINATED              389            13                     3        1            9.39268   57.7876 |
# | train_model_108ae_00008   TERMINATED              149             6                     6        1            7.17649   63.0379 |
# | train_model_108ae_00009   TERMINATED              155            16                     6        1            7.32038   59.3184 |
# +---------------------------------------------------------------------------------------------------------------------------------+
#
#
# ✅ Tuning Complete.
# 🏆 Best Hyperparameters found: {'n_estimators': 438, 'max_depth': 18, 'min_samples_split': 6}
# 📉 Lowest RMSE: 48.2815
#
# 📦 Promoting Best Model to Production Registry...
# 2026/01/11 21:49:35 WARNING mlflow.models.model: `artifact_path` is deprecated. Please use `name` instead.
# 🔒 Model Versioned at: runs:/a8d3661f24074317ba88419f561873b8/random_forest_model
#
# 🤖 Mock Inference Server Online...
# Downloading artifacts:   0%|          | 0/1 [00:00<?, ?it/s]
# Downloading artifacts:   0%|          | 0/5 [00:00<?, ?it/s]
#    Input: Patient Data [0.03, 0.05, ...]
#    Prediction: Disease Progression = 184.37
